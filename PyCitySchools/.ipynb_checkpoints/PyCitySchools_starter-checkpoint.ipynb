# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas Data Frames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# print(school_data)

# Combine the data into a single dataset
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])

school_data_complete.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %% [markdown]
# ## District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the overall passing rate (overall average score), i.e. (avg. math score + avg. reading score)/2
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
# print(school_data_complete.dtypes)

# Calculate the total number of schools
school_count = len(school_data_complete["school_name"].unique())
#print(school_count)

# Calculate the total number of students
student_count = len(school_data_complete["student_name"].unique())
#print(student_count)

# Calculate the total budget
total_budget = school_data["budget"].sum()
# print(total_budget)

# Calculate the average math score
avg_math_score = round(school_data_complete["math_score"].mean(),2)
# print(avg_math_score)

# Calculate the average reading score
avg_reading_score = round(school_data_complete["reading_score"].mean(),2)
# print(avg_reading_score)

# Calculate the percentage of students with a passing math score (70 or greater)
math_score_pass = school_data_complete[school_data_complete.math_score > 70]
math_passing = (math_score_pass['math_score'].count()/school_data_complete['student_name'].count())*100

# # print(math_passing)
# # # Calculate the percentage of students with a passing reading score (70 or greater)
reading_score_pass = school_data_complete[school_data_complete.reading_score > 70]
reading_passing = (reading_score_pass['reading_score'].count()/school_data_complete['student_name'].count())*100

# # Calculate the overall passing rate (overall average score), i.e. (avg. math score + avg. reading score)/2
overall_pass_rate = (math_passing + reading_passing)/2

# # Create a dataframe to hold the above results
d = {'Total Schools': (school_count), 
     'Total Students': (student_count), 
     'Total Budget':(total_budget), 
     'Average Math score':(avg_math_score), 
     'Average Reading score':(avg_reading_score),
     '% Passing Math':[round(math_passing,2)],
     '% Passing Reading':[round(reading_passing,2)],
     '% Overall Passing Rate':[round((math_passing+reading_passing)/2,2)]
    }
district_summary = pd.DataFrame(d)
district_summary = district_summary.loc[:,['Total Schools','Total Students','Total Budget','Average Math score',
                                       'Average Reading score','% Passing Math','% Passing Reading', '% Overall Passing Rate']]
district_summary['Total Budget'] = district_summary['Total Budget'].map("${:,.0f}".format)
district_summary['Total Students'] = district_summary['Total Students'].map("{:,.0f}".format)
district_summary['% Passing Math'] = district_summary['% Passing Math'].map("{:,}%".format)
district_summary['% Passing Reading'] = district_summary['% Passing Reading'].map("{:,}%".format)
district_summary['% Overall Passing Rate'] = district_summary['% Overall Passing Rate'].map("{:,}%".format)

district_summary
# # # Optional: give the displayed data cleaner formatting
# # # clean_school_summary_df = school_data_complete.dropna(how="any")
# # # clean_school_summary_df.count()
# Out:
#    Total Schools Total Students Total Budget  Average Math score  \
# 0             15         32,715  $24,649,428               78.99
#
#    Average Reading score % Passing Math % Passing Reading  \
# 0                  81.88         72.39%            82.97%
#
#   % Overall Passing Rate
# 0                 77.68%

# %% [raw]
# ## School Summary

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)
#
# * Create a dataframe to hold the above results

# %%
#Create an empty DataFrame to store results.  Each Series is added as they are created
#GroupBy object is created to construct calculated series for Averages
school_summary_df = pd.DataFrame(school_data[["school_name","type"]],index=school_data["School ID"])
groupby_school = school_data_complete.groupby("School ID")

#Set Index of school_data to School ID (above)

#Total Students
school_summary_df["Number of Students"] = groupby_school["Student ID"].count()

#Total School Budget
school_summary_df["School Budget"] = school_data["budget"]

#Per Student Budget
school_summary_df["Per Student Budget"] = school_summary_df["School Budget"]/school_summary_df["Number of Students"]

#Average Math Score
school_summary_df["Average Math Score"] = groupby_school["math_score"].mean()

#Average Reading Score
school_summary_df["Average Reading Score"] = groupby_school["reading_score"].mean()

#% Passing Math - I use the apply function and pass a function to filter the groupbby object
#groupby_school.apply(lambda df: len(df))
#groupby_school.apply(lambda df: len(df[df['math_score'] >= 70]))
school_summary_df["% Passing Math"]  = groupby_school.apply(lambda df: (len(df[df['math_score'] >= 70])/len(df))*100)

#% Passing Reading
school_summary_df["% Passing Reading"] = groupby_school.apply(lambda df: (len(df[df['reading_score'] >= 70])/len(df))*100)

#Overall Passing Rate (Average of the above two - use the series that were already created
school_summary_df["Overall Pass Rate"] = (school_summary_df["Average Math Score"]+ school_summary_df["Average Reading Score"])/2

school_summary_df.rename(columns={"type":"School Type"},inplace = True)
school_summary_print = school_summary_df.reset_index().set_index("school_name")[["School Type","Number of Students",\
                                                                                 "School Budget","Per Student Budget",\
                                                                                 "Average Math Score","Average Reading Score",\
                                                                                 "% Passing Math","% Passing Reading",\
                                                                                 "Overall Pass Rate"]]
school_summary_print.index.name = None
school_summary_print
# Out:
#                       School Type  Number of Students  School Budget  \
# Huang High School        District                2917        1910635
# Figueroa High School     District                2949        1884411
# Shelton High School       Charter                1761        1056600
# Hernandez High School    District                4635        3022020
# Griffin High School       Charter                1468         917500
# Wilson High School        Charter                2283        1319574
# Cabrera High School       Charter                1858        1081356
# Bailey High School       District                4976        3124928
# Holden High School        Charter                 427         248087
# Pena High School          Charter                 962         585858
# Wright High School        Charter                1800        1049400
# Rodriguez High School    District                3999        2547363
# Johnson High School      District                4761        3094650
# ...

# %%
# Using GroupBy in order to separate the data into fields according to "school_name" values
grouped_school_df = student_data.groupby(['school_name'])
# # The object returned is a "GroupBy" object and cannot be viewed normally...
# print(grouped_school_df)
score_report = pd.DataFrame(round(grouped_school_df.mean(),2))   
score_report = score_report.loc[:,['reading_score','math_score']]
score_report

# # In order to be visualized, a data function must be used...
# grouped_school_df.count().head(10)
# Out:
#                        reading_score  math_score
# school_name
# Bailey High School             81.03       77.05
# Cabrera High School            83.98       83.06
# Figueroa High School           81.16       76.71
# Ford High School               80.75       77.10
# Griffin High School            83.82       83.35
# Hernandez High School          80.93       77.29
# Holden High School             83.81       83.80
# Huang High School              81.18       76.63
# Johnson High School            80.97       77.07
# Pena High School               84.04       83.84
# Rodriguez High School          80.74       76.84
# Shelton High School            83.73       83.36
# Thomas High School             83.85       83.42
# Wilson High School             83.99       83.27
# Wright High School             83.96       83.68

# %% [markdown]
# ## Top Performing Schools (By Passing Rate)

# %%
# Sort and display the top five schools in overall passing rate

school_summary_df.sort_values(by=["Overall Pass Rate"], inplace = True, ascending=False)
school_summary_df.head(5)
# Out:
#                   school_name School Type  Number of Students  School Budget  \
# School ID
# 9            Pena High School     Charter                 962         585858
# 10         Wright High School     Charter                1800        1049400
# 8          Holden High School     Charter                 427         248087
# 14         Thomas High School     Charter                1635        1043130
# 5          Wilson High School     Charter                2283        1319574
#
#            Per Student Budget  Average Math Score  Average Reading Score  \
# School ID
# 9                       609.0           83.839917              84.044699
# 10                      583.0           83.682222              83.955000
# 8                       581.0           83.803279              83.814988
# 14                      638.0           83.418349              83.848930
# 5                       578.0           83.274201              83.989488
#
# ...

# %% [markdown]
# ## Bottom Performing Schools (By Passing Rate)

# %% [markdown]
# * Sort and display the five worst-performing schools

# %%
school_summary_df.sort_values(by=["Overall Pass Rate"], inplace = True, ascending=True)
school_summary_df.head(5)
# Out:
#                      school_name School Type  Number of Students  \
# School ID
# 11         Rodriguez High School    District                3999
# 0              Huang High School    District                2917
# 13              Ford High School    District                2739
# 1           Figueroa High School    District                2949
# 12           Johnson High School    District                4761
#
#            School Budget  Per Student Budget  Average Math Score  \
# School ID
# 11               2547363               637.0           76.842711
# 0                1910635               655.0           76.629414
# 13               1763916               644.0           77.102592
# 1                1884411               639.0           76.711767
# 12               3094650               650.0           77.072464
#
#            Average Reading Score  % Passing Math  % Passing Reading  \
# School ID
# 11                     80.744686       66.366592          80.220055
# ...

# %% [markdown]
# ## Math Scores by Grade

# %% [markdown]
# * Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
#   * Create a pandas series for each grade. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %%
math_by_grade = school_data_complete.groupby(["school_name", "grade"])["math_score"].mean().unstack()
math_by_grade.index.name = None
math_by_grade.columns.name = None
math_by_grade = math_by_grade[["9th", "10th", "11th", "12th"]]
math_by_grade
# Out:
#                              9th       10th       11th       12th
# Bailey High School     77.083676  76.996772  77.515588  76.492218
# Cabrera High School    83.094697  83.154506  82.765560  83.277487
# Figueroa High School   76.403037  76.539974  76.884344  77.151369
# Ford High School       77.361345  77.672316  76.918058  76.179963
# Griffin High School    82.044010  84.229064  83.842105  83.356164
# Hernandez High School  77.438495  77.337408  77.136029  77.186567
# Holden High School     83.787402  83.429825  85.000000  82.855422
# Huang High School      77.027251  75.908735  76.446602  77.225641
# Johnson High School    77.187857  76.691117  77.491653  76.863248
# Pena High School       83.625455  83.372000  84.328125  84.121547
# Rodriguez High School  76.859966  76.612500  76.395626  77.690748
# Shelton High School    83.420755  82.917411  83.383495  83.778976
# Thomas High School     83.590022  83.087886  83.498795  83.497041
# ...

# %% [markdown]
# ## Reading Score by Grade

# %% [markdown]
# * Perform the same operations as above for reading scores

# %%
read_by_grade = school_data_complete.groupby(["school_name", "grade"])["reading_score"].mean().unstack()
read_by_grade.index.name = None
read_by_grade.columns.names = [None]
read_by_grade = read_by_grade[["9th", "10th", "11th", "12th"]]
read_by_grade

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %%
# Sample bins. Feel free to create your own bins.
#spending_bins = [0, 585, 615, 645, 675]
#group_names = ["<$585", "$585-615", "$615-645", "$645-675"]
mean_summary = school_summary_df["Per Student Budget"].mean()
std_summary = school_summary_df["Per Student Budget"].std()
bin_list = [int(mean_summary-(2-std_dev)*std_summary) for std_dev in range(5)]
my_summary_bins = bin_list
my_group_names = [f"< ${bin_list[1]}", f"\${bin_list[1]}-\${bin_list[2]}",f"\${bin_list[2]}-\${bin_list[3]}", f"> \${bin_list[3]}"]

# %%
school_summary_print["Budget Category"]  = pd.cut(school_summary_print["Per Student Budget"],my_summary_bins, labels = my_group_names, include_lowest = True)
by_spending = school_summary_print.groupby("Budget Category").mean()[["Average Math Score", "Average Reading Score", "% Passing Math", "% Passing Reading", "Overall Pass Rate"]]
by_spending
# Out:
#                  Average Math Score  Average Reading Score  % Passing Math  \
# Budget Category
# < $591                    83.455399              83.933814       93.460096
# \$591-\$620               83.599686              83.885211       94.230858
# \$620-\$648               79.079225              81.891436       75.668212
# > \$648                   76.997210              81.027843       66.164813
#
#                  % Passing Reading  Overall Pass Rate
# Budget Category
# < $591                   96.610877          83.694607
# \$591-\$620              95.900287          83.742449
# \$620-\$648              86.106569          80.485330
# > \$648                  81.133951          79.012526

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %%
# Sample bins. Feel free to create your own bins.
# size_bins = [0, 1000, 2000, 5000]
# group_names = ["Small (<1000)", "Medium (1000-2000)", "Large (2000-5000)"]

mean_summary = school_summary_df["Number of Students"].mean()
std_summary = school_summary_df["Number of Students"].std()
bin_list = [int(mean_summary-(2-std_dev)*std_summary) for std_dev in range(5)]
my_summary_bins = bin_list
my_group_names = [f"< {bin_list[1]} students", f"{bin_list[1]}-{bin_list[2]} students",f"{bin_list[2]}-{bin_list[3]} students", f"> {bin_list[3]} students"]

# %%
school_summary_print["Size Category"] = pd.cut(school_summary_print["Number of Students"],my_summary_bins, labels = my_group_names, include_lowest = True)
by_size = school_summary_print.groupby("Size Category").mean()[["Average Math Score", "Average Reading Score", "% Passing Math", "% Passing Reading", "Overall Pass Rate"]]
by_size
# Out:
#                     Average Math Score  Average Reading Score  % Passing Math  \
# Size Category
# < 1190 students              83.821598              83.929843       93.550225
# 1190-2611 students           83.357937              83.885280       93.644365
# 2611-4032 students           76.821621              80.957921       66.587147
# > 4032 students              77.136883              80.978256       66.496861
#
#                     % Passing Reading  Overall Pass Rate
# Size Category
# < 1190 students             96.099437          83.875721
# 1190-2611 students          96.748840          83.621608
# 2611-4032 students          80.393681          78.889771
# > 4032 students             81.339570          79.057569

# %% [markdown]
# ## Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type.

# %%
school_summary_df.groupby("type").mean()[["Average Math Score", "Average Reading Score", "% Passing Math", "% Passing Reading", "Overall Pass Rate"]]
# Out:
#              Average Math Score  Average Reading Score  % Passing Math  \
# School Type
# Charter               83.473852              83.896421       93.620830
# District              76.956733              80.966636       66.548453
#
#              % Passing Reading  % Overall Passing Rate
# School Type
# Charter              96.586489               95.103660
# District             80.799062               73.673757

# %% [markdown]
# Observable Trends
#
# ~ Based upon the data, it is notable that academic success, as denoted by the Overall Pass Rate, appears to improve significantly as the number of students within the school decreases.
#
# ~ There does not appear to be a direct correlation between the Per Student Budget and academic success as measured by Overall Pass Rate.
#
# ~ Charter schools have a higher Overall Passing Rate than District School. with an especially large gap in Passing Math percentages.
